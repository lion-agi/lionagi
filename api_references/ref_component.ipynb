# %% [markdown]
# Best Practices: do not use `pydantic.BaseModel` methods.

# %% [markdown]
# ## ufuncs

# %% [markdown]
# ### DEPRECATION WARNING

# %% [markdown]
# timestamp is now really `timestamp(float)`, not `iso` format
#
# ### Remaining attr/methods (compatible with v1.0+)
#
#
# 1. `ln_id(str)`: frozen
# 2. `timestamp(float)`: frozen
# 3. `metadata(Note)`: constrained operations
# 4. `content(Any)`
# 5. `embedding(list[float])`
# 6. `extra_fields(dict[str, pydantic.fields.FieldInfo])`
# 7. `_converter_registry(ClassVar)`
# 8. `from_dict()`
# 9. `adapt_from()`
# 10. `register_converter()`
# 11. `from_obj()`
# 12. `all_fields`
# 13. `add_field()`
# 14. `update_field()`
# 15. `to_dict()`
# 16. `to_note()`
# 17. `adapt_to()`
# 18. `field_setattr()`
# 19. `field_hasattr()`
# 20. `field_getattr()`
# 21. `field_annotation()`
#
# ### the following methods are deprecated since **v0.3.0** and will be **removed** in **v1.0.0**:
#
# 1. `_all_fields` -> `self.all_fields`
# 2. `_field_annotations` -> `self.field_annotation()`
# 3. `to_json_str` -> `self.convert_to('json')`
# 4. `to_json_file` -> `self.convert_to('json_file')`
# 5. `to_xml` -> `self.convert_to('xml')`
# 6. `to_xml_file` -> `self.convert_to('xml_file')`
# 7. `to_pd_series` -> `self.convert_to('pd_series')`
# 8. `to_llama_index_node` -> `self.convert_to('llamaindex')`
# 9. `to_langchain_doc` -> `self.convert_to('langchain')`
# 10. `to_pd_dataframe` -> `self.convert_to('pd_dataframe')`
# 11. `_meta_pop` -> `self.metadata.pop()`
# 12. `_meta_get` -> `self.metadata.get()`
# 13. `_meta_set` -> `self.metadata.set()`
# 14. `_meta_insert` -> `self.metadata.insert()`
# 15. `_get_field_attr` -> `self.field_getattr()`
# 16. `_set_field_attr` -> `self.field_setattr()`
# 17. `_get_field_attr` -> `self.field_getattr()`
# 18. `_add_field` -> `self.add_field()`

# %% [markdown]
# ### API Reference

# %%
from lionagi.core.generic.component import Component
import lionfuncs as ln

# %% [markdown]
# #### 1. Basic

# %%
a = Component()
a.to_dict()
# Out:
# {'timestamp': 1728338581.962132,
#  'ln_id': 'lna9bdc9-909b0-f42f6a61dbab52e-f-dd2e2d8dca192c7',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'lion_class': 'Component'}

# %%
a.content = 1
a.to_dict()
# Out:
# {'timestamp': 1728338581.962132,
#  'ln_id': 'lna9bdc9-909b0-f42f6a61dbab52e-f-dd2e2d8dca192c7',
#  'metadata': {'last_updated': {'content': 1728338581.966503}},
#  'content': 1,
#  'embedding': [],
#  'lion_class': 'Component'}

# %%
a.class_name()
# Out:
# 'Component'

# %%
print("ln_id: \t\t\t", a.ln_id)  # unique lion id
print("created at: \t\t", a.timestamp)
print("metadata: \t\t", a.metadata)
print("content: \t\t", a.content)
print("extra_fields: \t\t", a.extra_fields)
# Out:
# ln_id: 			 lna9bdc9-909b0-f42f6a61dbab52e-f-dd2e2d8dca192c7
# created at: 		 1728338581.962132
# metadata: 		 {'last_updated': {'content': 1728338581.966503}}
# content: 		 1
# extra_fields: 		 {}

# %%
a.field_annotation("content")
# Out:
# {'content': ['Any']}

# %%
a.all_fields
# Out:
# {'timestamp': FieldInfo(annotation=float, required=False, default_factory=<lambda>, alias='created', alias_priority=2, title='Creation Timestamp', frozen=True),
#  'ln_id': FieldInfo(annotation=str, required=False, default_factory=id, title='Lion ID', description='Unique identifier for the element', frozen=True),
#  'metadata': FieldInfo(annotation=Note, required=False, default_factory=Note, description='Additional metadata for the component'),
#  'content': FieldInfo(annotation=Any, required=False, default=None, description='The main content of the Component'),
#  'embedding': FieldInfo(annotation=list[float], required=False, default_factory=list),
#  'extra_fields': FieldInfo(annotation=dict[str, Any], required=False, default_factory=dict)}

# %% [markdown]
# #### 2. Inherit from Component Class

# %%
from pydantic import Field

class Form(Component):
    form_name: str = Field(default="form", title="Form Name")
    date: str = "today"

a = Form()

# %%
a.field_hasattr("form_name", "title")
# Out:
# True

# %%
a.field_getattr("form_name", "title", None)
# Out:
# 'Form Name'

# %%
a.add_field(
    "welcome", annotation=str, default="new value", value="hello world again"
)

a.field_annotation("welcome")
# Out:
# {'welcome': ['str']}

# %%
print("default value: \t", a.field_getattr("welcome", "default", None))
print("current value: \t", getattr(a, "welcome", None))
# Out:
# default value: 	 new value
# current value: 	 hello world again

# %% [markdown]
# #### 3. Conversion Methods

# %%
print("json_str: \n\n", a.adapt_to("json_data"))
# Out:
# json_str:
#
#  {"timestamp": 1728338581.985232, "ln_id": "lnf44258-9-d6a4fb-1a542cadf-a07ee05d7c81d10bff89", "metadata": {"last_updated": {"welcome": 1728338581.995437}}, "content": null, "embedding": [], "form_name": "form", "date": "today", "welcome": "hello world again", "lion_class": "Form"}

# %%
print("dict: \n\n", a.to_dict())
# Out:
# dict:
#
#  {'timestamp': 1728338581.985232, 'ln_id': 'lnf44258-9-d6a4fb-1a542cadf-a07ee05d7c81d10bff89', 'metadata': {'last_updated': {'welcome': 1728338581.995437}}, 'content': None, 'embedding': [], 'form_name': 'form', 'date': 'today', 'welcome': 'hello world again', 'lion_class': 'Form'}

# %%
print("xml: \n\n", a.adapt_to("xml_data"))
# Out:
# xml:
#
#  <root><timestamp>1728338581.985232</timestamp><ln_id>lnf44258-9-d6a4fb-1a542cadf-a07ee05d7c81d10bff89</ln_id><metadata><last_updated><welcome>1728338581.995437</welcome></last_updated></metadata><content>None</content><embedding>[]</embedding><form_name>form</form_name><date>today</date><welcome>hello world again</welcome><lion_class>Form</lion_class></root>

# %%
print("pd.Series: \n\n", a.adapt_to("pd_series_data"))
# Out:
# pd.Series:
#
#  timestamp                                    1728338581.985232
# ln_id         lnf44258-9-d6a4fb-1a542cadf-a07ee05d7c81d10bff89
# metadata      {'last_updated': {'welcome': 1728338581.995437}}
# content                                                   None
# embedding                                                   []
# form_name                                                 form
# date                                                     today
# welcome                                      hello world again
# lion_class                                                Form
# dtype: object

# %%
llama_node = a.adapt_to("llamaindex_node")
print(type(llama_node))
ln.to_dict(llama_node)
# Out:
# <class 'llama_index.core.schema.TextNode'>
# {'id_': '31a1c7f2-76f4-4e02-8c5b-b5c740791d37',
#  'embedding': [],
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': '',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n',
#  'class_name': 'TextNode'}

# %%
langchain_doc = a.adapt_to("langchain_doc")
print(type(langchain_doc))
ln.to_dict(langchain_doc)
# Out:
# <class 'langchain_core.documents.base.Document'>
# {'id': None, 'metadata': {}, 'page_content': '', 'type': 'Document'}

# %% [markdown]
# ### from_obj method

# %% [markdown]
# #### dict, json with fuzzy parse

# %%
dict_obj = {"a": 1, "b": 2}

b = Component.from_obj(dict_obj)
b.to_dict()
# Out:
# {'timestamp': 1728338582.022487,
#  'ln_id': 'ln58c673d5-3-d6-c1d37cd8d0cb8d0a-95e554f28ef9aea',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'a': 1,
#  'b': 2,
#  'lion_class': 'Component'}

# %%
json_str_obj = '{"a": 1, "b": 2}'

a = Component.from_obj(json_str_obj)
a.to_dict()
# Out:
# {'timestamp': 1728338582.026279,
#  'ln_id': 'lnb4238486d01da-4325912348a-c7986-93d-0299ab291d',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'a': 1,
#  'b': 2,
#  'lion_class': 'Component'}

# %%
# the json str also supports fuzzy parse
# here is an incorrectly formated json_str for example (missing "}")
json_str_obj = '{"name": "John", "age": 30, "city": ["New York", "DC", "LA"]'

a = Component.from_obj(json_str_obj, fuzzy_parse=True)
a.to_dict()
# Out:
# {'timestamp': 1728338582.030085,
#  'ln_id': 'lnaf4ac1cf10c5-0163ed00ba-ccd50375-7-622cb45256c',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'name': 'John',
#  'age': 30,
#  'city': ['New York', 'DC', 'LA'],
#  'lion_class': 'Component'}

# %% [markdown]
# #### pandas series and dataframe

# %%
import pandas as pd

series_obj = pd.Series({"a": 1, "b": 2})
series_obj.to_dict()
# Out:
# {'a': 1, 'b': 2}

# %%
a = Component.from_dict({'a': 1, 'b': 2})

# %%
# you can create a component object from pandas series / dataframe
import pandas as pd

series_obj = pd.Series({"a": 1, "b": 2})

a = Component.from_obj(series_obj)
a.to_dict()
# Out:
# {'timestamp': 1728338582.040713,
#  'ln_id': 'lna499ca8f89e8-2b0-31c53ac1423a7b-c-e9bb4985c418',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'a': 1,
#  'b': 2,
#  'lion_class': 'Component'}

# %%
series_obj.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
df = pd.DataFrame({"a": [1, 2], "b": [3, 4]}, index=["row1", "row2"])
df
# Out:
#       a  b
# row1  1  3
# row2  2  4

# %%
# when you create component object from dataframe, the output will be a list of component objects
a = Component.from_obj(df)
type(a)
# Out:
# list

# %%
# if from df, the index of the row will be saved into the metadata

for i in a:
    print(i.to_dict())
# Out:
# {'timestamp': 1728338582.065502, 'ln_id': 'lna5ee7deea-3090326321d65-2ba33-8a5b7-62ae36967d', 'metadata': {}, 'content': None, 'embedding': [], 'a': 1, 'b': 3, 'lion_class': 'Component'}
# {'timestamp': 1728338582.066856, 'ln_id': 'lnceb500728c3b237-59756836-7bea-5f98d-d1e85d3a31', 'metadata': {}, 'content': None, 'embedding': [], 'a': 2, 'b': 4, 'lion_class': 'Component'}

# %% [markdown]
# #### LlamaIndex and LangChain

# %%
llama_node.to_dict()
# Out:
# {'id_': '31a1c7f2-76f4-4e02-8c5b-b5c740791d37',
#  'embedding': [],
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': '',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n',
#  'class_name': 'TextNode'}

# %%
llama_node
# Out:
# TextNode(id_='31a1c7f2-76f4-4e02-8c5b-b5c740791d37', embedding=[], metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
Component.adapt_from(llama_node, "llamaindex_node").class_name()
# Out:
# 'Component'

# %%
type(llama_node)
# Out:
# llama_index.core.schema.TextNode

# %%
a = Component.from_obj(llama_node)
type(a)
# Out:
# lionagi.core.generic.component.Component

# %%
a.to_dict()
# Out:
# {'timestamp': 1728338582.119356,
#  'ln_id': 'ln6a2805c2-23d8a-19885faee-2c-d162403e691065b813',
#  'metadata': {},
#  'content': '',
#  'embedding': [],
#  'llama_meta': {'llama_index_id_': '31a1c7f2-76f4-4e02-8c5b-b5c740791d37',
#   'llama_index_metadata': {},
#   'llama_index_excluded_embed_metadata_keys': [],
#   'llama_index_excluded_llm_metadata_keys': [],
#   'llama_index_relationships': {},
#   'llama_index_mimetype': 'text/plain',
#   'llama_index_start_char_idx': None,
#   'llama_index_end_char_idx': None,
#   'llama_index_text_template': '{metadata_str}\n\n{content}',
#   'llama_index_metadata_template': '{key}: {value}',
#   'llama_index_metadata_seperator': '\n',
#   'llama_index_class_name': 'TextNode'},
#  'lion_class': 'Component'}

# %%
a = Component.from_obj(langchain_doc)
type(a)
# Out:
# lionagi.core.generic.component.Component

# %%
langchain_doc.page_content = "1"

# %%
langchain_doc.to_json()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
#  'kwargs': {'page_content': '1', 'type': 'Document'}}

# %%
langchain_doc.model_dump()
# Out:
# {'id': None, 'metadata': {}, 'page_content': '1', 'type': 'Document'}

# %%
ln.to_dict(langchain_doc)
# Out:
# {'id': None, 'metadata': {}, 'page_content': '1', 'type': 'Document'}

# %%
a.to_dict()
# Out:
# {'timestamp': 1728338582.126557,
#  'ln_id': 'lnb79689d5610557e1a7c181-17854-b04-3409-6bfb3d84',
#  'metadata': {},
#  'content': None,
#  'embedding': [],
#  'lc_meta': {'lc_id': None,
#   'lc_metadata': {},
#   'lc_page_content': '',
#   'lc_type': 'Document'},
#  'lion_class': 'Component'}

# %% [markdown]
# ### MetaData Manipulation

# %%
a.add_field("welcome", annotation=str, default="new value", value="hello world again")
a.welcome = "hi"

print(a.metadata)
type(a.metadata)        # note is an advanced dict
# Out:
# {'last_updated': {'welcome': 1728338582.147794}}
# lion_core.generic.note.Note

# %%
# you cannot directly modify the metadata by assigning a new value
try:
    a.metadata = {}
except Exception as e:
    print(e)
# Out:
# Cannot directly assign to metadata.

# %% [markdown]
# use the following methods to modify the metadata

# %%
# however, you can modify the metadata in the following ways
a.metadata.insert("new_key2", "new_value2")
a.metadata
# Out:
# {'last_updated': {'welcome': 1728338582.147794}, 'new_key2': 'new_value2'}

# %%
# the meta insert also support nested data structure

a.metadata.insert(["nested", 0], {"a": 1, "b": 2})

# %%
a.metadata
# Out:
# {'last_updated': {'welcome': 1728338582.147794}, 'new_key2': 'new_value2', 'nested': [{'a': 1, 'b': 2}]}

# %%
# similarly you can get a deeply nested value from meta data

a.metadata.get(["nested", 0, "a"])
# Out:
# 1

# %%
a.metadata
# Out:
# {'last_updated': {'welcome': 1728338582.147794}, 'new_key2': 'new_value2', 'nested': [{'a': 1, 'b': 2}]}
