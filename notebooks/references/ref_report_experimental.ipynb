# %%
from lionagi.experimental.report.report import Report

# %%
report = Report(assignment="a, b -> c")

# %%
report.input_fields
# Out:
# ['a', 'b']

# %%
report.output_fields
# Out:
# ['c']

# %%
report.work_fields
# Out:
# {'a': None, 'b': None, 'c': None}

# %%
report.filled
# Out:
# False

# %%
report.workable
# Out:
# ERROR:root:Field 'a' is required to work on the report.
# False

# %%
report.fill(a=3, b=4)

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': None}

# %%
report
# Out:
# Report(id_='54ff02081ffa284aaf7856a8463c00c9', timestamp='2024-04-23T19:36:35.646567+00:00', assignment='a, b -> c', forms={'a, b -> c': Form(id_='aee55782e172d0a8ac18525e1dabc42d', timestamp='2024-04-23T19:36:35.646604+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c'], a=3, b=4, c=None)}, form_assignments=['a, b -> c'], form_template=<class 'lionagi.experimental.form.form.Form'>, input_fields=['a', 'b'], output_fields=['c'], a=3, b=4, c=None)

# %%
report.workable
# Out:
# True

# %%
report.next_forms
# Out:
# [Form(id_='aee55782e172d0a8ac18525e1dabc42d', timestamp='2024-04-23T19:36:35.646604+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c'], a=3, b=4, c=None)]

# %%
report.fill(c=4)

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': 4}

# %%
report.workable
# Out:
# False

# %%
report.filled
# Out:
# True

# %%
report.next_forms is None
# Out:
# True

# %%
report = Report(
    assignment="a, b -> h",
    form_assignments=["a, b -> c", "a -> e", "b -> f", "c -> g", "e, f, g -> h"],
    a=3,
    b=4,
)

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': None, 'e': None, 'f': None, 'g': None, 'h': None}

# %%
for _, k in report.forms.items():
    print(k.work_fields)
# Out:
# {'a': 3, 'b': 4, 'c': None}
# {'a': 3, 'e': None}
# {'b': 4, 'f': None}
# {'c': None, 'g': None}
# {'e': None, 'f': None, 'g': None, 'h': None}

# %%
report.forms
# Out:
# {'a, b -> c': Form(id_='3223a0363f8e7b876b37e2bec3c08665', timestamp='2024-04-23T19:36:35.719380+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c'], a=3, b=4),
#  'a -> e': Form(id_='25c925f8aee62b51903c84ff2d52427b', timestamp='2024-04-23T19:36:35.719397+00:00', assignment='a -> e', input_fields=['a'], output_fields=['e'], e=None, a=3),
#  'b -> f': Form(id_='801d6dea050726d67003fa1299fab7f1', timestamp='2024-04-23T19:36:35.719433+00:00', assignment='b -> f', input_fields=['b'], output_fields=['f'], f=None, b=4),
#  'c -> g': Form(id_='6d55c186e262abb593d94532f7bfe560', timestamp='2024-04-23T19:36:35.719460+00:00', assignment='c -> g', input_fields=['c'], output_fields=['g'], g=None),
#  'e, f, g -> h': Form(id_='5c98239e51a6a5761a126918d5b104b3', timestamp='2024-04-23T19:36:35.719486+00:00', assignment='e, f, g -> h', input_fields=['e', 'f', 'g'], output_fields=['h'], h=None)}

# %%
new_forms = {i: report.form_template(assignment=i) for i in report.form_assignments}

# %%
new_forms
# Out:
# {'a, b -> c': Form(id_='b777018777f8db7c76216f90005e3483', timestamp='2024-04-23T19:36:35.733379+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c']),
#  'a -> e': Form(id_='e52a7652496d847ac93bbcf525f498d5', timestamp='2024-04-23T19:36:35.733408+00:00', assignment='a -> e', input_fields=['a'], output_fields=['e']),
#  'b -> f': Form(id_='71a38246ff913ac79ed134a3d414ee9c', timestamp='2024-04-23T19:36:35.733422+00:00', assignment='b -> f', input_fields=['b'], output_fields=['f']),
#  'c -> g': Form(id_='f2dc5c2a6ee65686662520d319838a2c', timestamp='2024-04-23T19:36:35.733436+00:00', assignment='c -> g', input_fields=['c'], output_fields=['g']),
#  'e, f, g -> h': Form(id_='5e477628af162e0edab3c02a67355a41', timestamp='2024-04-23T19:36:35.733445+00:00', assignment='e, f, g -> h', input_fields=['e', 'f', 'g'], output_fields=['h'])}

# %%
for k, v in new_forms.items():
    if k not in report.forms:
        report.forms[k] = v

# %%
report.forms
# Out:
# {'a, b -> c': Form(id_='3223a0363f8e7b876b37e2bec3c08665', timestamp='2024-04-23T19:36:35.719380+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c'], a=3, b=4),
#  'a -> e': Form(id_='25c925f8aee62b51903c84ff2d52427b', timestamp='2024-04-23T19:36:35.719397+00:00', assignment='a -> e', input_fields=['a'], output_fields=['e'], e=None, a=3),
#  'b -> f': Form(id_='801d6dea050726d67003fa1299fab7f1', timestamp='2024-04-23T19:36:35.719433+00:00', assignment='b -> f', input_fields=['b'], output_fields=['f'], f=None, b=4),
#  'c -> g': Form(id_='6d55c186e262abb593d94532f7bfe560', timestamp='2024-04-23T19:36:35.719460+00:00', assignment='c -> g', input_fields=['c'], output_fields=['g'], g=None),
#  'e, f, g -> h': Form(id_='5c98239e51a6a5761a126918d5b104b3', timestamp='2024-04-23T19:36:35.719486+00:00', assignment='e, f, g -> h', input_fields=['e', 'f', 'g'], output_fields=['h'], h=None)}

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': None, 'e': None, 'f': None, 'g': None, 'h': None}

# %%
report
# Out:
# Report(id_='ffa062906fc291c09659acca89294c91', timestamp='2024-04-23T19:36:35.719348+00:00', assignment='a, b -> h', forms={'a, b -> c': Form(id_='3223a0363f8e7b876b37e2bec3c08665', timestamp='2024-04-23T19:36:35.719380+00:00', assignment='a, b -> c', input_fields=['a', 'b'], output_fields=['c'], a=3, b=4), 'a -> e': Form(id_='25c925f8aee62b51903c84ff2d52427b', timestamp='2024-04-23T19:36:35.719397+00:00', assignment='a -> e', input_fields=['a'], output_fields=['e'], e=None, a=3), 'b -> f': Form(id_='801d6dea050726d67003fa1299fab7f1', timestamp='2024-04-23T19:36:35.719433+00:00', assignment='b -> f', input_fields=['b'], output_fields=['f'], f=None, b=4), 'c -> g': Form(id_='6d55c186e262abb593d94532f7bfe560', timestamp='2024-04-23T19:36:35.719460+00:00', assignment='c -> g', input_fields=['c'], output_fields=['g'], g=None), 'e, f, g -> h': Form(id_='5c98239e51a6a5761a126918d5b104b3', timestamp='2024-04-23T19:36:35.719486+00:00', assignment='e, f, g -> h', input_fields=['e', 'f', 'g'], output_fields=['h'], h=None)}, form_assignments=['a, b -> c', 'a -> e', 'b -> f', 'c -> g', 'e, f, g -> h'], form_template=<class 'lionagi.experimental.form.form.Form'>, input_fields=['a', 'b'], output_fields=['h'], e=None, f=None, g=None, h=None, a=3, b=4)

# %%
report.model_fields
# Out:
# {'id_': FieldInfo(annotation=str, required=False, default_factory=create_id, alias_priority=2, validation_alias=AliasChoices(choices=['node_id', 'ID', 'id']), title='ID', description='A 32-char unique hash identifier for the node.'),
#  'timestamp': FieldInfo(annotation=str, required=False, default_factory=<lambda>, description='The timestamp of when the node was created.'),
#  'assignment': FieldInfo(annotation=str, required=True, examples=['input1, input2 -> output']),
#  'forms': FieldInfo(annotation=dict[str, Form], required=False, default_factory=dict, description='A dictionary of forms related to the report, in {assignment: Form} format.'),
#  'form_assignments': FieldInfo(annotation=list, required=False, default=[], description='assignment for the report', examples=[['a, b -> c', 'a -> e', 'b -> f', 'c -> g', 'e, f, g -> h']]),
#  'form_template': FieldInfo(annotation=Type[Form], required=False, default=<class 'lionagi.experimental.form.form.Form'>, description='The template for the forms in the report.'),
#  'input_fields': FieldInfo(annotation=list[str], required=False, default_factory=list),
#  'output_fields': FieldInfo(annotation=list[str], required=False, default_factory=list),
#  'a': FieldInfo(annotation=Any, required=False),
#  'b': FieldInfo(annotation=Any, required=False),
#  'c': FieldInfo(annotation=Any, required=False),
#  'e': FieldInfo(annotation=Any, required=False),
#  'f': FieldInfo(annotation=Any, required=False),
#  'g': FieldInfo(annotation=Any, required=False),
#  'h': FieldInfo(annotation=Any, required=False)}

# %%
report.workable
# Out:
# True

# %%
report.filled
# Out:
# False

# %%
report.fill(c=5, e=6, f=7, g=8, h=10)

# %%
report.filled
# Out:
# True

# %%
report.workable
# Out:
# False

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': 5, 'e': 6, 'f': 7, 'g': 8, 'h': 10}

# %%
report.fill(c="xx", e="yy")

# %%
report.work_fields
# Out:
# {'a': 3, 'b': 4, 'c': 5, 'e': 6, 'f': 7, 'g': 8, 'h': 10}
