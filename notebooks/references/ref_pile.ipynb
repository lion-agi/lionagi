# %% [markdown]
# ### LionAGI pile
#
# pile object is used throughout lionagi system

# %%
import lionagi as li

# %%
# let us create some nodes and put into pile

nodes1 = [li.Node(content=i) for i in ["A", "B", "C"]]
nodes2 = [li.Node(content=i) for i in ["D", "E", "F"]]

p1 = li.pile(nodes1)
p2 = li.pile(nodes2)

# %%
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  3890f3a0982202cf2aab5aa7e1062628  2024-05-28T22:21:28.787068       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
#
#   content embedding                                          relations  \
# 0       A        []  {'in': {'ln_id': 'd615bc7fc277e838bcce67009b1d...
# 1       B        []  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...
# 2       C        []  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node

# %%
## addition

(p1 + p2).to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  3890f3a0982202cf2aab5aa7e1062628  2024-05-28T22:21:28.787068       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 3  11195b2588e34328a9bc1b96c96f759c  2024-05-28T22:21:28.787250       {}
# 4  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 5  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#   content embedding                                          relations  \
# 0       A        []  {'in': {'ln_id': 'd615bc7fc277e838bcce67009b1d...
# 1       B        []  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...
# 2       C        []  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...
# 3       D        []  {'in': {'ln_id': '9c984b525d3d3318295d31c0315a...
# 4       E        []  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...
# 5       F        []  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node
# 3       Node
# 4       Node
# 5       Node

# %%
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  3890f3a0982202cf2aab5aa7e1062628  2024-05-28T22:21:28.787068       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
#
#   content embedding                                          relations  \
# 0       A        []  {'in': {'ln_id': 'd615bc7fc277e838bcce67009b1d...
# 1       B        []  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...
# 2       C        []  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node

# %%
## subtraction

try:
    (p1 - p2).to_df()
except Exception as e:
    print(e)
# Out:
# Item not found. Item: '                              ln_id                     created metadata  \
# 0  11195b2588e34328a9bc1b96c96f759c  2024-05-28T22:21:28.787250       {}
# 1  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 2  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#   content embedding                                          relations  \
# 0       D        []  {'in': {'ln_id': '9c984b525d3d3318295d31c0315a...
# 1       E        []  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...
# 2       F        []  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node  '.

# %%
## containment

p1 in p2
# Out:
# False

# %%
## inclusion

print(p1.include(p2))
p1.to_df()
# Out:
# True
#                               ln_id                     created metadata  \
# 0  3890f3a0982202cf2aab5aa7e1062628  2024-05-28T22:21:28.787068       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 3  11195b2588e34328a9bc1b96c96f759c  2024-05-28T22:21:28.787250       {}
# 4  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 5  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#   content embedding                                          relations  \
# 0       A        []  {'in': {'ln_id': 'd615bc7fc277e838bcce67009b1d...
# 1       B        []  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...
# 2       C        []  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...
# 3       D        []  {'in': {'ln_id': '9c984b525d3d3318295d31c0315a...
# 4       E        []  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...
# 5       F        []  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node
# 3       Node
# 4       Node
# 5       Node

# %%
## exclusion

print(p1.exclude(p2))
p1.to_df()
# Out:
# True
#                               ln_id                     created metadata  \
# 0  3890f3a0982202cf2aab5aa7e1062628  2024-05-28T22:21:28.787068       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 3  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 4  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#   content embedding                                          relations  \
# 0       A        []  {'in': {'ln_id': 'd615bc7fc277e838bcce67009b1d...
# 1       B        []  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...
# 2       C        []  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...
# 3       E        []  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...
# 4       F        []  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...
#
#   lion_class
# 0       Node
# 1       Node
# 2       Node
# 3       Node
# 4       Node

# %%
## get item

aa = p2[0]
aa
# Out:
# ln_id         11195b2588e34328a9bc1b96c96f759c
# created             2024-05-28T22:21:28.787250
# metadata                                    {}
# content                                      D
# embedding                                   []
# relations                               [0, 0]
# lion_class                                Node
# dtype: object

# %%
## set item

p1[0] = li.Node(content="have a good day")
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  b488ddb828be84155467b37e22c7faaf  2024-05-28T22:21:28.879052       {}
# 1  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 3  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 4  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#            content embedding  \
# 0  have a good day        []
# 1                B        []
# 2                C        []
# 3                E        []
# 4                F        []
#
#                                            relations lion_class
# 0  {'in': {'ln_id': '7efd48e3c36c4348964c889a767e...       Node
# 1  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...       Node
# 2  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...       Node
# 3  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...       Node
# 4  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...       Node

# %%
# p1[:4] = li.pile([li.Node(content="have a good day") for i in range(4)])

# %%
p1.insert(0, li.Node(content="have a good day"))

# %%
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  0fa0e11293e77d2c30605f8a0d9cb69a  2024-05-28T22:21:28.901160       {}
# 1  b488ddb828be84155467b37e22c7faaf  2024-05-28T22:21:28.879052       {}
# 2  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 3  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 4  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 5  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
#
#            content embedding  \
# 0  have a good day        []
# 1  have a good day        []
# 2                B        []
# 3                C        []
# 4                E        []
# 5                F        []
#
#                                            relations lion_class
# 0  {'in': {'ln_id': 'd6db76c9465a1d9cc0ba29cc7c45...       Node
# 1  {'in': {'ln_id': '7efd48e3c36c4348964c889a767e...       Node
# 2  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...       Node
# 3  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...       Node
# 4  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...       Node
# 5  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...       Node

# %%
## other
node = li.Node(content="hello world")
p1 += node
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  0fa0e11293e77d2c30605f8a0d9cb69a  2024-05-28T22:21:28.901160       {}
# 1  b488ddb828be84155467b37e22c7faaf  2024-05-28T22:21:28.879052       {}
# 2  919923fa2f2204f7e84b0246e98bf5c8  2024-05-28T22:21:28.787141       {}
# 3  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 4  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 5  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
# 6  5cb88e48e5fd904313bcc8e11eb193b0  2024-05-28T22:21:28.922625       {}
#
#            content embedding  \
# 0  have a good day        []
# 1  have a good day        []
# 2                B        []
# 3                C        []
# 4                E        []
# 5                F        []
# 6      hello world        []
#
#                                            relations lion_class
# 0  {'in': {'ln_id': 'd6db76c9465a1d9cc0ba29cc7c45...       Node
# 1  {'in': {'ln_id': '7efd48e3c36c4348964c889a767e...       Node
# 2  {'in': {'ln_id': '04b16e0894a53865b12eabb29f6c...       Node
# 3  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...       Node
# 4  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...       Node
# 5  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...       Node
# 6  {'in': {'ln_id': '85ec64eb905f6573fb33c7c309aa...       Node

# %%
# you can remove an element from the pile by -= an object directly
p1 -= nodes1[1]  # the original sequence second element was B
p1.to_df()
# Out:
#                               ln_id                     created metadata  \
# 0  0fa0e11293e77d2c30605f8a0d9cb69a  2024-05-28T22:21:28.901160       {}
# 1  b488ddb828be84155467b37e22c7faaf  2024-05-28T22:21:28.879052       {}
# 2  ca08c00fd599d3ec11be55b08d2e75bc  2024-05-28T22:21:28.787180       {}
# 3  ade38469486a5cd3c3444630730bdbe2  2024-05-28T22:21:28.787287       {}
# 4  661ce361c1b89ece0663edc3067de288  2024-05-28T22:21:28.787322       {}
# 5  5cb88e48e5fd904313bcc8e11eb193b0  2024-05-28T22:21:28.922625       {}
#
#            content embedding  \
# 0  have a good day        []
# 1  have a good day        []
# 2                C        []
# 3                E        []
# 4                F        []
# 5      hello world        []
#
#                                            relations lion_class
# 0  {'in': {'ln_id': 'd6db76c9465a1d9cc0ba29cc7c45...       Node
# 1  {'in': {'ln_id': '7efd48e3c36c4348964c889a767e...       Node
# 2  {'in': {'ln_id': '0815c1ddacbf4b9c76c6537e364a...       Node
# 3  {'in': {'ln_id': '092fc5dc93c5b4ffa9f31b7cda73...       Node
# 4  {'in': {'ln_id': 'e63a5ffcd17bc8e06bf0db8a0bfa...       Node
# 5  {'in': {'ln_id': '85ec64eb905f6573fb33c7c309aa...       Node

# %%
# p1.to_graph()

# %%
nodes1[1] in p1
# Out:
# False

# %%
try:
    p1 - nodes1[1]
except Exception as e:
    print(e)
# Out:
# Item not found. Item: 'ln_id         919923fa2f2204f7e84b0246e98bf5c8
# created             2024-05-28T22:21:28.787141
# metadata                                    {}
# content                                      B
# embedding                                   []
# relations                               [0, 0]
# lion_class                                Node
# dtype: object'.

# %%
a = li.pile()
b = li.pile()

list(a + b)
# Out:
# []

# %%
len([True, True])
# Out:
# 2
