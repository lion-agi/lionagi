# %%
from lionagi.core.generic.abc.component import Component

# %% [markdown]
# ## Base Universal Attributes

# %%
a = Component()
print(a)
# Out:
# ln_id         027b30d583e3a5364dc2bfa29a1c6f88
# created             2024-05-12T14:16:41.073562
# metadata                                    {}
# content                                   None
# class_name                           Component
# dtype: object

# %%
a.content = 1

# %%
a
# Out:
# ln_id                          027b30d583e3a5364dc2bfa29a1c6f88
# created                              2024-05-12T14:16:41.073562
# metadata      {'last_updated': {'content': '2024-05-12T14:16...
# content                                                       1
# class_name                                            Component
# dtype: object

# %%
a.class_name
# Out:
# 'Component'

# %%
print("ln_id: \t\t\t", a.ln_id)                 # unique lion id
print("created at: \t\t", a.timestamp)      
print("metadata: \t\t", a.metadata)
print("content: \t\t", a.content)
print("extra_fields: \t\t", a.extra_fields)
# Out:
# ln_id: 			 027b30d583e3a5364dc2bfa29a1c6f88
# created at: 		 2024-05-12T14:16:41.073562
# metadata: 		 {'last_updated': {'content': '2024-05-12T14:16:41.077326'}}
# content: 		 1
# extra_fields: 		 {}

# %%
a._field_annotations
# Out:
# {'ln_id': ['str'],
#  'timestamp': ['str'],
#  'metadata': ['dict'],
#  'extra_fields': ['dict'],
#  'content': ['Any']}

# %%
a._all_fields
# Out:
# {'ln_id': FieldInfo(annotation=str, required=False, default_factory=create_id, alias_priority=2, validation_alias=AliasChoices(choices=['node_id', 'ID', 'id']), title='ID', description='A 32-char unique hash identifier.', frozen=True),
#  'timestamp': FieldInfo(annotation=str, required=False, default_factory=<lambda>, alias='created', alias_priority=2, validation_alias=AliasChoices(choices=['created_on', 'creation_date']), title='Creation Timestamp', description='The UTC timestamp of creation', frozen=True),
#  'metadata': FieldInfo(annotation=dict[str, Any], required=False, default_factory=dict, alias_priority=2, validation_alias=AliasChoices(choices=['meta', 'info']), description='Additional metadata for the component.'),
#  'extra_fields': FieldInfo(annotation=dict[str, Any], required=False, default_factory=dict, alias_priority=2, validation_alias=AliasChoices(choices=['extra', 'additional_fields', 'schema_extra', 'extra_schema']), description='Additional fields for the component.'),
#  'content': FieldInfo(annotation=Any, required=False, alias_priority=2, validation_alias=AliasChoices(choices=['text', 'page_content', 'chunk_content', 'data']), description='The optional content of the node.')}

# %% [markdown]
# ## Inherit from Component Class

# %%
from pydantic import Field

class Form(Component):
    form_name: str = Field(default="form", title="Form Name")
    date: str = "today"
    
a = Form()

# %%
# check the details of a specific field
a._field_has_attr("form_name", "title")
# Out:
# True

# %%
a._get_field_attr("form_name", "title")
# Out:
# 'Form Name'

# %%
a._field_annotations
# Out:
# {'ln_id': ['str'],
#  'timestamp': ['str'],
#  'metadata': ['dict'],
#  'extra_fields': ['dict'],
#  'content': ['Any'],
#  'form_name': ['str'],
#  'date': ['str']}

# %%
a._add_field(
    field="welcome", annotation=str, default="new value", value="hello world again"
)

a._field_annotations
# Out:
# {'ln_id': ['str'],
#  'timestamp': ['str'],
#  'metadata': ['dict'],
#  'extra_fields': ['dict'],
#  'content': ['Any'],
#  'form_name': ['str'],
#  'date': ['str'],
#  'welcome': ['str']}

# %%
print("default value: \t", a._get_field_attr("welcome", "default", None))
print("current value: \t", getattr(a, "welcome", None))
# Out:
# default value: 	 new value
# current value: 	 hello world again

# %% [markdown]
# ### to_obj methods

# %%
print("json_str: \n\n", a.to_json_str())
# Out:
# json_str:
#
#  {"ln_id": "7513f596e17695a1dc4d291859178b89", "created": "2024-05-12T14:16:41.099930", "metadata": {"last_updated": {"welcome": "2024-05-12T14:16:41.113716"}}, "content": null, "form_name": "form", "date": "today", "welcome": "hello world again"}

# %%
print("dict: \n\n", a.to_dict())
# Out:
# dict:
#
#  {'ln_id': '7513f596e17695a1dc4d291859178b89', 'created': '2024-05-12T14:16:41.099930', 'metadata': {'last_updated': {'welcome': '2024-05-12T14:16:41.113716'}}, 'content': None, 'form_name': 'form', 'date': 'today', 'welcome': 'hello world again'}

# %%
print("xml: \n\n", a.to_xml())
# Out:
# xml:
#
#  <Form><ln_id>7513f596e17695a1dc4d291859178b89</ln_id><created>2024-05-12T14:16:41.099930</created><metadata><last_updated><welcome>2024-05-12T14:16:41.113716</welcome></last_updated></metadata><content>None</content><form_name>form</form_name><date>today</date><welcome>hello world again</welcome></Form>

# %%
print("pd.Series: \n\n", a.to_pd_series())
# Out:
# pd.Series:
#
#  ln_id                         7513f596e17695a1dc4d291859178b89
# created                             2024-05-12T14:16:41.099930
# metadata     {'last_updated': {'welcome': '2024-05-12T14:16...
# content                                                   None
# form_name                                                 form
# date                                                     today
# welcome                                      hello world again
# dtype: object

# %%
llama_node = a.to_llama_index_node()
type(llama_node)
# Out:
# llama_index.core.schema.TextNode

# %%
llama_node.to_dict()
# Out:
# {'id_': 'a909f90b-f3d3-4455-a5f1-e3c06874e514',
#  'embedding': None,
#  'metadata': {'last_updated': {'welcome': '2024-05-12T14:16:41.113716'}},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': 'None',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n',
#  'class_name': 'TextNode'}

# %%
langchain_doc = a.to_langchain_doc()
type(langchain_doc)
# Out:
# langchain_core.documents.base.Document

# %%
langchain_doc.to_json()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
#  'kwargs': {'page_content': '',
#   'ln_id': '7513f596e17695a1dc4d291859178b89',
#   'created': '2024-05-12T14:16:41.099930',
#   'metadata': {'last_updated': {'welcome': '2024-05-12T14:16:41.113716'}},
#   'form_name': 'form',
#   'date': 'today',
#   'welcome': 'hello world again'}}

# %% [markdown]
# ### from_obj method

# %% [markdown]
# #### dict, json with fuzzy parse

# %%
dict_obj = {"a": 1, "b": 2}

b = Component.from_obj(dict_obj)
b.to_dict()
# Out:
# {'ln_id': 'cad09bbcd763653ddc5a2dca89aeeecf',
#  'created': '2024-05-12T14:16:41.756091',
#  'metadata': {'a': 1, 'b': 2},
#  'content': None}

# %%
json_str_obj = '{"a": 1, "b": 2}'

a = Component.from_obj(json_str_obj)
a.to_dict()
# Out:
# {'ln_id': '8ffa1818ed3ffece88ccc978219a363a',
#  'created': '2024-05-12T14:16:41.759920',
#  'metadata': {'a': 1, 'b': 2},
#  'content': None}

# %%
# the json str also supports fuzzy parse
# here is an incorrectly formated json_str for example (missing "}")
json_str_obj = '{"name": "John", "age": 30, "city": ["New York", "DC", "LA"]'

a = Component.from_obj(json_str_obj, fuzzy_parse=True)
a.to_dict()
# Out:
# {'ln_id': 'd9385adc489811102d716f302c0e6bb4',
#  'created': '2024-05-12T14:16:41.763854',
#  'metadata': {'name': 'John', 'age': 30, 'city': ['New York', 'DC', 'LA']},
#  'content': None}

# %% [markdown]
# #### pandas series and dataframe

# %%
# you can create a component object from pandas series / dataframe
import pandas as pd

series_obj = pd.Series({"a": 1, "b": 2})

a = Component.from_obj(series_obj)
a.to_dict()
# Out:
# {'ln_id': 'b0ccb64b52a6229e9f620fc779e9c9aa',
#  'created': '2024-05-12T14:16:41.768154',
#  'metadata': {'a': 1, 'b': 2},
#  'content': None}

# %%
series_obj.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
df = pd.DataFrame({"a": [1, 2], "b": [3, 4]}, index=["row1", "row2"])
df
# Out:
#       a  b
# row1  1  3
# row2  2  4

# %%
# when you create component object from dataframe, the output will be a list of component objects
a = Component.from_obj(df)
type(a)
# Out:
# list

# %%
# if from df, the index of the row will be saved into the metadata

for i in a:
    print(i.to_dict())
# Out:
# {'ln_id': 'f68152119d442d906e3bdb660ca983ba', 'created': '2024-05-12T14:16:41.787941', 'metadata': {'a': 1, 'b': 3}, 'content': None}
# {'ln_id': 'bb946328d8b2a11c7d0bc6cfc8b710a4', 'created': '2024-05-12T14:16:41.788001', 'metadata': {'a': 2, 'b': 4}, 'content': None}

# %% [markdown]
# #### LlamaIndex and LangChain

# %%
a = Component.from_obj(llama_node)
type(a)
# Out:
# lionagi.core.generic.abc.component.Component

# %%
a.to_dict()
# Out:
# {'ln_id': '5cfa96811baee28be76793b41bf49af8',
#  'created': '2024-05-12T14:16:41.795206',
#  'metadata': {'last_updated': {'welcome': '2024-05-12T14:16:41.113716'},
#   'embedding': None,
#   'excluded_embed_metadata_keys': [],
#   'excluded_llm_metadata_keys': [],
#   'start_char_idx': None,
#   'end_char_idx': None,
#   'text_template': '{metadata_str}\n\n{content}',
#   'metadata_template': '{key}: {value}',
#   'metadata_seperator': '\n',
#   'llama_index_class': 'TextNode',
#   'llama_index_id': 'a909f90b-f3d3-4455-a5f1-e3c06874e514',
#   'llama_index_relationships': {}},
#  'content': 'None'}

# %%
a = Component.from_obj(langchain_doc)
type(a)
# Out:
# lionagi.core.generic.abc.component.Component

# %%
a.to_dict()
# Out:
# {'ln_id': '7513f596e17695a1dc4d291859178b89',
#  'created': '2024-05-12T14:16:41.099930',
#  'metadata': {'langchain': 1,
#   'lc_type': 'constructor',
#   'lc_id': ['langchain', 'schema', 'document', 'Document']},
#  'content': '',
#  'form_name': 'form',
#  'date': 'today',
#  'welcome': 'hello world again'}

# %%
a.welcome = "hi"

# %%
a.to_dict()
# Out:
# {'ln_id': '7513f596e17695a1dc4d291859178b89',
#  'created': '2024-05-12T14:16:41.099930',
#  'metadata': {'langchain': 1,
#   'lc_type': 'constructor',
#   'lc_id': ['langchain', 'schema', 'document', 'Document'],
#   'last_updated': {'welcome': '2024-05-12T14:16:41.810035'}},
#  'content': '',
#  'form_name': 'form',
#  'date': 'today',
#  'welcome': 'hi'}

# %% [markdown]
# ### MetaData Manipulation

# %%
a.welcome = "hi"
a.metadata["last_updated"]
# Out:
# {'welcome': '2024-05-12T14:16:41.810035'}

# %%
a.welcome = "hi"
a.metadata["last_updated"]
# Out:
# {'welcome': '2024-05-12T14:16:41.810035'}

# %%
a.metadata
# Out:
# {'langchain': 1,
#  'lc_type': 'constructor',
#  'lc_id': ['langchain', 'schema', 'document', 'Document'],
#  'last_updated': {'welcome': '2024-05-12T14:16:41.810035'}}

# %%
# you cannot directly modify the metadata by assigning a new value
a.metadata = {}
a.metadata
# Out:
# {'langchain': 1,
#  'lc_type': 'constructor',
#  'lc_id': ['langchain', 'schema', 'document', 'Document'],
#  'last_updated': {'welcome': '2024-05-12T14:16:41.810035'}}

# %% [markdown]
# use the following methods to modify the metadata

# %%
# however, you can modify the metadata in the following ways


a._meta_insert("new_key2", "new_value2")
a._meta_set("langchain", 5)

# a.metadata["new_key"] = "new_value"
# you can access and modify the value of metadata directly
# but we do not recommend it, it might lose information or cause unexpected behavior

# %%
a.metadata
# Out:
# {'langchain': 5,
#  'lc_type': 'constructor',
#  'lc_id': ['langchain', 'schema', 'document', 'Document'],
#  'last_updated': {'welcome': '2024-05-12T14:16:41.810035'},
#  'new_key2': 'new_value2'}

# %%
# the meta insert also support nested data structure

a._meta_insert(["nested", 0], {"a": 1, "b": 2})

# %%
a.metadata
# Out:
# {'langchain': 5,
#  'lc_type': 'constructor',
#  'lc_id': ['langchain', 'schema', 'document', 'Document'],
#  'last_updated': {'welcome': '2024-05-12T14:16:41.810035'},
#  'new_key2': 'new_value2',
#  'nested': [{'a': 1, 'b': 2}]}

# %%
# similarly you can get a deeply nested value from meta data

a._meta_get(["nested", 0, "a"])
# Out:
# 1

# %%
a.metadata
# Out:
# {'langchain': 5,
#  'lc_type': 'constructor',
#  'lc_id': ['langchain', 'schema', 'document', 'Document'],
#  'last_updated': {'welcome': '2024-05-12T14:16:41.810035'},
#  'new_key2': 'new_value2',
#  'nested': [{'a': 1, 'b': 2}]}
