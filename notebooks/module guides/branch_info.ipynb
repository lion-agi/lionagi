# %% [markdown]
# # Branch Information

# %%
def multiply(number1: float, number2: float):
    """
    Perform multiplication on two numbers.

    Args:
        number1: First number to multiply.
        number2: Second number to multiply.

    Returns:
        The product of number1 and number2.

    """
    return number1 * number2


# and now some messages
system = "you are asked to perform as a function picker and parameter provider"
task = "Think step by step, understand the following basic math question and provide parameters for function calling."


question = "There are [basketball, football, backpack, water bottle, strawberry, tennis ball, rockets]. each comes in four different colors, what is the number of unique kinds of ball?"
question2 = "There are three fruits in total, each with 2 different colors, how many unique kinds of fruits are there?"

context1 = {"Question1": question, "question2": question2}

# by_default, tools are not used, you need to specify
# tools = True, allows all tools to be available to use
# tools = schema / Tool Object let you to specify which tools are allowed to use

# %%
import lionagi as li

branch = li.Branch(system=system, tools=multiply)
out = await branch.chat(instruction=task, context=context1, tools=True)

# %%
out

# %%
branch.to_df()
# Out:
#                               ln_id       message_type  \
# 0  d71e4715cb502ddcaf84bcfa9817ebc0             System
# 1  c65a3fb8e7832f36a95a75b7e7bab31f        Instruction
# 2  a59b77c0d9eb8f2b5d6f831258678648  AssistantResponse
# 3  6eb00d792c5d506faf8316a83defa11a      ActionRequest
# 4  334564f7a8b77309aa3ba95957582612      ActionRequest
# 5  175b012e4380bd2649bd3e8d738ad0b2     ActionResponse
# 6  c89b6e0abae2799375011261603e0fd8     ActionResponse
#
#                     timestamp       role  \
# 0  2024-05-28T00:15:38.360711     system
# 1  2024-05-28T00:15:38.361640       user
# 2  2024-05-28T00:15:46.066265  assistant
# 3  2024-05-28T00:15:46.066501  assistant
# 4  2024-05-28T00:15:46.066591  assistant
# 5  2024-05-28T00:15:46.066875  assistant
# 6  2024-05-28T00:15:46.067035  assistant
#
#                                              content  \
# 0  {'system_info': 'you are asked to perform as a...
# 1  {'instruction': 'Think step by step, understan...
# 2  {'assistant_response': 'Let's break down each ...
# 3  {'action_request': {'function': 'multiply', 'a...
# 4  {'action_request': {'function': 'multiply', 'a...
# 5  {'action_response': {'function': 'multiply', '...
# 6  {'action_response': {'function': 'multiply', '...
#
#                                             metadata  \
# 0  {'last_updated': {'recipient': '2024-05-28T00:...
# 1  {'last_updated': {'sender': '2024-05-28T00:15:...
# 2  {'last_updated': {'sender': '2024-05-28T00:15:...
# 3  {'last_updated': {'function': '2024-05-28T00:1...
# 4  {'last_updated': {'function': '2024-05-28T00:1...
# 5  {'last_updated': {'function': '2024-05-28T00:1...
# 6  {'last_updated': {'function': '2024-05-28T00:1...
#
#                              sender                         recipient
# 0                            system  17c4ca216e9164cb4045b898634d298a
# 1                              user  17c4ca216e9164cb4045b898634d298a
# 2  17c4ca216e9164cb4045b898634d298a                              user
# 3  17c4ca216e9164cb4045b898634d298a  7ffcad399b771aa1bace152790d8a31a
# 4  17c4ca216e9164cb4045b898634d298a  7ffcad399b771aa1bace152790d8a31a
# 5  7ffcad399b771aa1bace152790d8a31a  17c4ca216e9164cb4045b898634d298a
# 6  7ffcad399b771aa1bace152790d8a31a  17c4ca216e9164cb4045b898634d298a

# %%
from IPython.display import display, Markdown
Markdown(branch.messages[2].content["assistant_response"])
# Out:
# Let's break down each question step by step to understand the parameters needed for the function calls.
#
# ### Question 1:
# - **Items**: basketball, football, backpack, water bottle, strawberry, tennis ball, rockets.
# - **Items that are balls**: basketball, football, tennis ball.
# - **Number of balls**: 3 (basketball, football, tennis ball).
# - **Colors**: 4 different colors.
#
# To find the number of unique kinds of balls, we multiply the number of balls by the number of colors:
# \[ \text{Number of unique kinds of balls} = 3 \times 4 \]
#
# ### Question 2:
# - **Number of fruits**: 3.
# - **Colors**: 2 different colors.
#
# To find the number of unique kinds of fruits, we multiply the number of fruits by the number of colors:
# \[ \text{Number of unique kinds of fruits} = 3 \times 2 \]
#
# ### Parameters for Function Calls:
# For Question 1:
# - `number1`: 3 (number of balls)
# - `number2`: 4 (number of colors)
#
# For Question 2:
# - `number1`: 3 (number of fruits)
# - `number2`: 2 (number of colors)
#
# ### Multi-Tool Use:
# We can use the `multi_tool_use.parallel` function to call the `functions.multiply` function for both questions simultaneously.
#
# Here are the parameters for the `multi_tool_use.parallel` function:
#
# ```json
# {
#   "tool_uses": [
#     {
#       "recipient_name": "functions.multiply",
#       "parameters": {
#         "number1": 3,
#         "number2": 4
#       }
#     },
#     {
#       "recipient_name": "functions.multiply",
#       "parameters": {
#         "number1": 3,
#         "number2": 2
#       }
#     }
#   ]
# }
# ```
#
# Let's proceed with this.

# %%
from lionagi.libs import to_readable_dict

response = branch.messages[2]
print(to_readable_dict(response.metadata))
# Out:
# {
#     "last_updated": {
#         "sender": "2024-05-28T00:15:46.066390",
#         "recipient": "2024-05-28T00:15:46.066404"
#     },
#     "extra": {
#         "id": "chatcmpl-9Ten4srJpKczKNX1TbTR0A2u3V7vP",
#         "object": "chat.completion",
#         "created": 1716855338,
#         "model": "gpt-4o-2024-05-13",
#         "usage": {
#             "prompt_tokens": 165,
#             "completion_tokens": 452,
#             "total_tokens": 617,
#             "expense": 0.007605
#         },
#         "system_fingerprint": "fp_43dfabdef1",
#         "index": 0,
#         "logprobs": null,
#         "finish_reason": "tool_calls"
#     }
# }
